# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-20b", streaming=True)

# %%
question = "Write a short poem about the beauty of nature."

res = llm.stream(question)

for chunk in res:
    print(chunk.content, end="")
# Out:
# Beneath the sky’s wide, silver hush,
# Leaves whisper in a quiet rush—
# Sunlight spills in amber streams,
# And rivers hum their ancient dreams.
#
# Mountains stand in silent grace,
# Their peaks like thoughts in endless space.
# Flowers bloom, a fleeting blush,
# Nature paints her own soft hush.
