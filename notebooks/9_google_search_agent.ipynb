# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
agent = create_agent(
    model=llm,
    tools = [search.run],
    system_prompt="You are a helpful assistant that can answer questions using Google Search.",
    checkpointer = MemorySaver()
)

# %%
question = "total runs?"

# %%
response = agent.invoke(
    {"messages":[{"role":"user","content":question}]},
    {"configurable":{"thread_id":"google_search_agent"}}
    )

# %%
print(response["messages"][-1].content)
# Out:
# In the 2025 ICC Women’s Cricket World Cup final:
#
# - **India Women** scored **298 runs** (7 wickets down).
# - **South Africa Women** were all out for **246 runs**.
#
# So the total runs scored in the match were **298 + 246 = 544 runs**.
