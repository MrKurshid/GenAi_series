# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-20b")

# %%
res = llm.invoke("Write a short poem about the beauty of nature.")

print(res.content)
# Out:
# Gentle rivers hum a silver song,
# Leaves whisper secrets to the wind,
# Mountains stand in quiet grace,
# Stars paint night with silver ink.
#
# Every breath of earth’s soft pulse,
# Reminds us that we’re alive—
# In nature’s arms, we find our pulse,
# And in its beauty, we thrive.
