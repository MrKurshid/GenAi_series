# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
documents = [
    "Machine learning is a subset of artificial intelligence",
    "Deep learning uses neural networks with multiple layers",
    "Python is a programming language popular for data science",
    "India won the cricket world cup in 2011",
    "AI models can understand and generate human language"
]

# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="nomic-embed-text",
)

# %%
vector = embeddings.embed_documents(documents)
# Out:
# 5

# %%
len(vector[0])

# %% [markdown]
# #### Store Vector Embeddings in Vector DB

# %%
from langchain_chroma import Chroma

# %%
vector_store = Chroma.from_texts(
    texts=documents,
    embedding=embeddings,
    persist_directory="./vector_db"
)

# %%
query = "Data Science"
result = vector_store.similarity_search(query=query, k=2)
result
# Out:
# [Document(id='1f91972d-b1e6-44ed-a51a-8995e2f3d562', metadata={}, page_content='Python is a programming language popular for data science'),
#  Document(id='3f34d844-0e51-42b4-ad18-3b6ad853eabe', metadata={}, page_content='Machine learning is a subset of artificial intelligence')]
